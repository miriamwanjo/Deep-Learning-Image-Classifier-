# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.
#
# Please make sure if you are running this notebook in the workspace that you have chosen GPU rather than CPU mode.

# %%
# Imports here
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import time
import json
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([
                                    
                                      transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406], 
                                                          [0.229, 0.224, 0.225])])

validation_transforms = transforms.Compose([
                                             transforms.Resize(256),
                                           transforms.CenterCrop(224),
                                            transforms.ToTensor(),
                                           transforms.Normalize([0.485, 0.456, 0.406], 
                                                                [0.229, 0.224, 0.225])])

# TODO: Load the datasets with ImageFolder
trainset = datasets.ImageFolder(train_dir,transform=train_transforms)
testset = datasets.ImageFolder(test_dir,transform=test_transforms)
validset = datasets.ImageFolder(valid_dir, transform=validation_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(trainset, batch_size = 64, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size = 32, shuffle=True)
validloader = torch.utils.data.DataLoader(validset, batch_size = 32, shuffle = True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = models.densenet121(pretrained=True)
model
# Out:
# /opt/conda/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.torch/models/densenet121-a639ec97.pth
# 100%|██████████| 32342954/32342954 [00:01<00:00, 22449630.69it/s]
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %%
# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False
# build a feed-forward network  
model.classifier = nn.Sequential(nn.Linear(1024, 256),
                                 nn.ReLU(),
                                 nn.Dropout(p=0.5),
                                 nn.Linear(256, 102),
                                 nn.LogSoftmax(dim=1))

# define the criterion and optimizer
criterion = nn.NLLLoss()

# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
model.to(device);

# %%
# Train the network
epochs = 10
print_every = 5
steps = 0


# change to cuda
model.to(device)

for epoch in range(epochs):
    running_loss = 0
    for inputs, labels in trainloader:
        steps += 1
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        logps = model.forward(inputs)
        loss = criterion(logps, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
            
        if steps % print_every == 0:
            valid_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                    
                for inputs, labels in validloader:
                    
                    inputs, labels = inputs.to(device), labels.to(device)
                    logps = model.forward(inputs)
                    batch_loss = criterion(logps, labels)
                    valid_loss += batch_loss.item()
                        
                        # Calculate accuracy
                    ps = torch.exp(logps).data
                    equals = (labels.data == ps.max(1)[1])
                    accuracy += equals.type_as(torch.FloatTensor()).mean()
                    
                    print(f"Epoch {epoch+1}/{epochs}.. "
                              f"Train loss: {running_loss/print_every:.3f}.. "
                              f"Valid loss: {valid_loss/len(validloader):.3f}.."
                              f"Valid accuracy: {accuracy/len(validloader):.3f}")
                running_loss = 0
            model.train()
# Out:
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 0.173..Valid accuracy: 0.001
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 0.347..Valid accuracy: 0.001
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 0.521..Valid accuracy: 0.002
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 0.691..Valid accuracy: 0.005
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 0.867..Valid accuracy: 0.006
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 1.044..Valid accuracy: 0.006
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 1.212..Valid accuracy: 0.011
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 1.389..Valid accuracy: 0.012
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 1.566..Valid accuracy: 0.012
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 1.738..Valid accuracy: 0.012
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 1.907..Valid accuracy: 0.013
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 2.086..Valid accuracy: 0.013
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 2.256..Valid accuracy: 0.017
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 2.426..Valid accuracy: 0.019
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 2.595..Valid accuracy: 0.022
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 2.769..Valid accuracy: 0.022
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 2.940..Valid accuracy: 0.022
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 3.114..Valid accuracy: 0.022
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 3.296..Valid accuracy: 0.022
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 3.470..Valid accuracy: 0.022
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 3.642..Valid accuracy: 0.023
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 3.811..Valid accuracy: 0.024
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 3.988..Valid accuracy: 0.025
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 4.163..Valid accuracy: 0.026
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 4.334..Valid accuracy: 0.028
# Epoch 1/10.. Train loss: 4.588.. Valid loss: 4.513..Valid accuracy: 0.030
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 0.167..Valid accuracy: 0.002
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 0.334..Valid accuracy: 0.006
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 0.506..Valid accuracy: 0.007
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 0.668..Valid accuracy: 0.013
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 0.836..Valid accuracy: 0.017
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 1.010..Valid accuracy: 0.020
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 1.180..Valid accuracy: 0.020
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 1.350..Valid accuracy: 0.022
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 1.525..Valid accuracy: 0.024
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 1.705..Valid accuracy: 0.025
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 1.879..Valid accuracy: 0.029
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 2.056..Valid accuracy: 0.031
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 2.225..Valid accuracy: 0.036
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 2.391..Valid accuracy: 0.037
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 2.561..Valid accuracy: 0.038
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 2.737..Valid accuracy: 0.040
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 2.903..Valid accuracy: 0.042
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 3.064..Valid accuracy: 0.044
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 3.229..Valid accuracy: 0.046
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 3.399..Valid accuracy: 0.047
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 3.572..Valid accuracy: 0.048
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 3.747..Valid accuracy: 0.048
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 3.909..Valid accuracy: 0.050
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 4.077..Valid accuracy: 0.052
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 4.252..Valid accuracy: 0.053
# Epoch 1/10.. Train loss: 4.495.. Valid loss: 4.418..Valid accuracy: 0.057
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 0.170..Valid accuracy: 0.002
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 0.332..Valid accuracy: 0.007
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 0.504..Valid accuracy: 0.010
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 0.668..Valid accuracy: 0.016
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 0.829..Valid accuracy: 0.023
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 0.995..Valid accuracy: 0.029
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 1.163..Valid accuracy: 0.031
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 1.320..Valid accuracy: 0.041
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 1.481..Valid accuracy: 0.046
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 1.645..Valid accuracy: 0.049
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 1.814..Valid accuracy: 0.054
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 1.976..Valid accuracy: 0.061
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 2.146..Valid accuracy: 0.062
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 2.313..Valid accuracy: 0.067
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 2.482..Valid accuracy: 0.071
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 2.650..Valid accuracy: 0.076
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 2.817..Valid accuracy: 0.082
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 2.986..Valid accuracy: 0.088
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 3.150..Valid accuracy: 0.091
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 3.318..Valid accuracy: 0.096
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 3.485..Valid accuracy: 0.100
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 3.650..Valid accuracy: 0.106
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 3.819..Valid accuracy: 0.112
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 3.984..Valid accuracy: 0.118
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 4.154..Valid accuracy: 0.123
# Epoch 1/10.. Train loss: 4.510.. Valid loss: 4.333..Valid accuracy: 0.125
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 0.166..Valid accuracy: 0.005
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 0.333..Valid accuracy: 0.010
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 0.496..Valid accuracy: 0.018
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 0.655..Valid accuracy: 0.029
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 0.818..Valid accuracy: 0.038
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 0.981..Valid accuracy: 0.046
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 1.143..Valid accuracy: 0.052
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 1.309..Valid accuracy: 0.058
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 1.468..Valid accuracy: 0.065
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 1.631..Valid accuracy: 0.071
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 1.797..Valid accuracy: 0.077
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 1.964..Valid accuracy: 0.082
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 2.129..Valid accuracy: 0.087
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 2.296..Valid accuracy: 0.090
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 2.455..Valid accuracy: 0.094
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 2.614..Valid accuracy: 0.103
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 2.769..Valid accuracy: 0.113
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 2.934..Valid accuracy: 0.120
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 3.094..Valid accuracy: 0.124
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 3.257..Valid accuracy: 0.131
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 3.421..Valid accuracy: 0.137
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 3.593..Valid accuracy: 0.139
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 3.761..Valid accuracy: 0.143
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 3.925..Valid accuracy: 0.150
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 4.098..Valid accuracy: 0.154
# Epoch 1/10.. Train loss: 4.396.. Valid loss: 4.262..Valid accuracy: 0.162
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 0.158..Valid accuracy: 0.011
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 0.319..Valid accuracy: 0.018
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 0.483..Valid accuracy: 0.023
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 0.642..Valid accuracy: 0.028
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 0.802..Valid accuracy: 0.035
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 0.964..Valid accuracy: 0.041
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 1.132..Valid accuracy: 0.042
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 1.295..Valid accuracy: 0.044
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 1.442..Valid accuracy: 0.056
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 1.604..Valid accuracy: 0.061
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 1.761..Valid accuracy: 0.071
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 1.929..Valid accuracy: 0.076
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 2.091..Valid accuracy: 0.082
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 2.247..Valid accuracy: 0.093
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 2.418..Valid accuracy: 0.096
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 2.569..Valid accuracy: 0.107
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 2.734..Valid accuracy: 0.113
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 2.893..Valid accuracy: 0.119
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 3.053..Valid accuracy: 0.125
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 3.211..Valid accuracy: 0.131
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 3.372..Valid accuracy: 0.139
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 3.533..Valid accuracy: 0.147
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 3.685..Valid accuracy: 0.156
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 3.847..Valid accuracy: 0.161
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 4.008..Valid accuracy: 0.168
# Epoch 1/10.. Train loss: 4.272.. Valid loss: 4.174..Valid accuracy: 0.175
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 0.152..Valid accuracy: 0.008
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 0.312..Valid accuracy: 0.014
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 0.468..Valid accuracy: 0.017
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 0.636..Valid accuracy: 0.019
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 0.784..Valid accuracy: 0.028
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 0.940..Valid accuracy: 0.035
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 1.095..Valid accuracy: 0.041
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 1.250..Valid accuracy: 0.047
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 1.409..Valid accuracy: 0.052
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 1.560..Valid accuracy: 0.059
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 1.712..Valid accuracy: 0.069
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 1.867..Valid accuracy: 0.076
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 2.016..Valid accuracy: 0.087
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 2.168..Valid accuracy: 0.095
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 2.330..Valid accuracy: 0.102
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 2.491..Valid accuracy: 0.108
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 2.649..Valid accuracy: 0.114
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 2.804..Valid accuracy: 0.123
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 2.967..Valid accuracy: 0.127
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 3.125..Valid accuracy: 0.136
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 3.279..Valid accuracy: 0.139
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 3.429..Valid accuracy: 0.147
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 3.591..Valid accuracy: 0.150
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 3.753..Valid accuracy: 0.153
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 3.913..Valid accuracy: 0.155
# Epoch 1/10.. Train loss: 4.202.. Valid loss: 4.062..Valid accuracy: 0.161
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 0.157..Valid accuracy: 0.008
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 0.309..Valid accuracy: 0.014
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 0.466..Valid accuracy: 0.018
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 0.619..Valid accuracy: 0.024
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 0.762..Valid accuracy: 0.031
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 0.912..Valid accuracy: 0.037
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 1.076..Valid accuracy: 0.038
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 1.219..Valid accuracy: 0.043
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 1.377..Valid accuracy: 0.047
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 1.532..Valid accuracy: 0.050
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 1.685..Valid accuracy: 0.058
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 1.841..Valid accuracy: 0.062
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 1.990..Valid accuracy: 0.070
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 2.140..Valid accuracy: 0.077
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 2.294..Valid accuracy: 0.083
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 2.449..Valid accuracy: 0.087
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 2.602..Valid accuracy: 0.093
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 2.758..Valid accuracy: 0.095
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 2.905..Valid accuracy: 0.100
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 3.066..Valid accuracy: 0.102
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 3.220..Valid accuracy: 0.107
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 3.370..Valid accuracy: 0.112
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 3.531..Valid accuracy: 0.114
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 3.671..Valid accuracy: 0.121
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 3.826..Valid accuracy: 0.129
# Epoch 1/10.. Train loss: 4.178.. Valid loss: 3.984..Valid accuracy: 0.133
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 0.152..Valid accuracy: 0.006
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 0.308..Valid accuracy: 0.012
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 0.466..Valid accuracy: 0.017
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 0.614..Valid accuracy: 0.025
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 0.765..Valid accuracy: 0.031
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 0.931..Valid accuracy: 0.034
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 1.078..Valid accuracy: 0.040
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 1.231..Valid accuracy: 0.046
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 1.380..Valid accuracy: 0.053
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 1.533..Valid accuracy: 0.058
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 1.688..Valid accuracy: 0.061
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 1.846..Valid accuracy: 0.066
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 1.987..Valid accuracy: 0.076
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 2.142..Valid accuracy: 0.079
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 2.285..Valid accuracy: 0.087
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 2.440..Valid accuracy: 0.089
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 2.595..Valid accuracy: 0.093
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 2.740..Valid accuracy: 0.100
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 2.885..Valid accuracy: 0.108
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 3.032..Valid accuracy: 0.115
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 3.182..Valid accuracy: 0.124
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 3.334..Valid accuracy: 0.129
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 3.477..Valid accuracy: 0.137
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 3.618..Valid accuracy: 0.144
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 3.771..Valid accuracy: 0.150
# Epoch 1/10.. Train loss: 4.019.. Valid loss: 3.914..Valid accuracy: 0.161
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 0.159..Valid accuracy: 0.006
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 0.300..Valid accuracy: 0.017
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 0.456..Valid accuracy: 0.020
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 0.587..Valid accuracy: 0.031
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 0.734..Valid accuracy: 0.035
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 0.882..Valid accuracy: 0.044
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 1.029..Valid accuracy: 0.049
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 1.174..Valid accuracy: 0.058
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 1.314..Valid accuracy: 0.072
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 1.464..Valid accuracy: 0.077
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 1.603..Valid accuracy: 0.089
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 1.740..Valid accuracy: 0.102
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 1.891..Valid accuracy: 0.109
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 2.033..Valid accuracy: 0.117
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 2.180..Valid accuracy: 0.124
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 2.333..Valid accuracy: 0.129
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 2.475..Valid accuracy: 0.136
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 2.631..Valid accuracy: 0.145
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 2.786..Valid accuracy: 0.148
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 2.921..Valid accuracy: 0.160
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 3.058..Valid accuracy: 0.173
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 3.189..Valid accuracy: 0.186
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 3.330..Valid accuracy: 0.197
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 3.471..Valid accuracy: 0.208
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 3.609..Valid accuracy: 0.224
# Epoch 1/10.. Train loss: 4.062.. Valid loss: 3.768..Valid accuracy: 0.230
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 0.139..Valid accuracy: 0.010
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 0.279..Valid accuracy: 0.018
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 0.412..Valid accuracy: 0.029
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 0.549..Valid accuracy: 0.037
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 0.705..Valid accuracy: 0.040
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 0.840..Valid accuracy: 0.048
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 0.971..Valid accuracy: 0.062
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 1.111..Valid accuracy: 0.070
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 1.253..Valid accuracy: 0.078
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 1.399..Valid accuracy: 0.088
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 1.539..Valid accuracy: 0.097
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 1.680..Valid accuracy: 0.111
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 1.830..Valid accuracy: 0.118
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 1.968..Valid accuracy: 0.127
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 2.102..Valid accuracy: 0.138
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 2.240..Valid accuracy: 0.148
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 2.399..Valid accuracy: 0.150
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 2.548..Valid accuracy: 0.156
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 2.685..Valid accuracy: 0.163
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 2.830..Valid accuracy: 0.172
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 2.956..Valid accuracy: 0.186
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 3.089..Valid accuracy: 0.198
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 3.224..Valid accuracy: 0.209
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 3.364..Valid accuracy: 0.216
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 3.508..Valid accuracy: 0.224
# Epoch 1/10.. Train loss: 3.950.. Valid loss: 3.638..Valid accuracy: 0.234
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 0.145..Valid accuracy: 0.006
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 0.291..Valid accuracy: 0.013
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 0.420..Valid accuracy: 0.020
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 0.556..Valid accuracy: 0.026
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 0.690..Valid accuracy: 0.032
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 0.840..Valid accuracy: 0.038
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 0.977..Valid accuracy: 0.048
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 1.112..Valid accuracy: 0.060
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 1.249..Valid accuracy: 0.069
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 1.380..Valid accuracy: 0.081
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 1.512..Valid accuracy: 0.088
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 1.640..Valid accuracy: 0.100
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 1.775..Valid accuracy: 0.111
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 1.911..Valid accuracy: 0.121
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 2.051..Valid accuracy: 0.129
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 2.182..Valid accuracy: 0.138
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 2.314..Valid accuracy: 0.149
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 2.456..Valid accuracy: 0.156
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 2.595..Valid accuracy: 0.165
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 2.733..Valid accuracy: 0.175
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 2.869..Valid accuracy: 0.185
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 3.011..Valid accuracy: 0.191
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 3.144..Valid accuracy: 0.200
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 3.273..Valid accuracy: 0.212
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 3.421..Valid accuracy: 0.214
# Epoch 1/10.. Train loss: 3.797.. Valid loss: 3.556..Valid accuracy: 0.225
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 0.135..Valid accuracy: 0.006
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 0.268..Valid accuracy: 0.016
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 0.398..Valid accuracy: 0.029
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 0.540..Valid accuracy: 0.040
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 0.668..Valid accuracy: 0.052
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 0.787..Valid accuracy: 0.065
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 0.924..Valid accuracy: 0.073
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 1.060..Valid accuracy: 0.087
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 1.190..Valid accuracy: 0.095
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 1.313..Valid accuracy: 0.107
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 1.436..Valid accuracy: 0.119
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 1.571..Valid accuracy: 0.126
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 1.702..Valid accuracy: 0.136
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 1.844..Valid accuracy: 0.145
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 1.979..Valid accuracy: 0.156
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 2.108..Valid accuracy: 0.171
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 2.242..Valid accuracy: 0.180
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 2.376..Valid accuracy: 0.191
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 2.517..Valid accuracy: 0.200
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 2.648..Valid accuracy: 0.210
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 2.783..Valid accuracy: 0.222
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 2.904..Valid accuracy: 0.233
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 3.043..Valid accuracy: 0.242
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 3.165..Valid accuracy: 0.258
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 3.295..Valid accuracy: 0.269
# Epoch 1/10.. Train loss: 3.813.. Valid loss: 3.421..Valid accuracy: 0.282
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 0.119..Valid accuracy: 0.013
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 0.252..Valid accuracy: 0.024
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 0.378..Valid accuracy: 0.037
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 0.504..Valid accuracy: 0.048
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 0.631..Valid accuracy: 0.059
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 0.758..Valid accuracy: 0.069
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 0.889..Valid accuracy: 0.082
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 1.010..Valid accuracy: 0.095
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 1.133..Valid accuracy: 0.108
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 1.264..Valid accuracy: 0.120
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 1.391..Valid accuracy: 0.131
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 1.532..Valid accuracy: 0.137
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 1.653..Valid accuracy: 0.150
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 1.773..Valid accuracy: 0.165
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 1.905..Valid accuracy: 0.174
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 2.038..Valid accuracy: 0.186
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 2.155..Valid accuracy: 0.200
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 2.295..Valid accuracy: 0.208
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 2.424..Valid accuracy: 0.219
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 2.549..Valid accuracy: 0.231
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 2.679..Valid accuracy: 0.243
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 2.813..Valid accuracy: 0.256
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 2.941..Valid accuracy: 0.270
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 3.081..Valid accuracy: 0.279
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 3.205..Valid accuracy: 0.293
# Epoch 1/10.. Train loss: 3.633.. Valid loss: 3.332..Valid accuracy: 0.308
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 0.119..Valid accuracy: 0.017
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 0.249..Valid accuracy: 0.028
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 0.360..Valid accuracy: 0.044
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 0.485..Valid accuracy: 0.054
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 0.612..Valid accuracy: 0.070
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 0.738..Valid accuracy: 0.083
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 0.859..Valid accuracy: 0.100
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 0.991..Valid accuracy: 0.113
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 1.113..Valid accuracy: 0.130
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 1.231..Valid accuracy: 0.143
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 1.347..Valid accuracy: 0.160
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 1.462..Valid accuracy: 0.174
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 1.603..Valid accuracy: 0.183
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 1.736..Valid accuracy: 0.192
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 1.868..Valid accuracy: 0.200
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 1.983..Valid accuracy: 0.216
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 2.119..Valid accuracy: 0.230
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 2.239..Valid accuracy: 0.248
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 2.364..Valid accuracy: 0.261
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 2.495..Valid accuracy: 0.269
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 2.616..Valid accuracy: 0.285
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 2.732..Valid accuracy: 0.302
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 2.841..Valid accuracy: 0.323
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 2.959..Valid accuracy: 0.340
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 3.081..Valid accuracy: 0.356
# Epoch 1/10.. Train loss: 3.616.. Valid loss: 3.206..Valid accuracy: 0.371
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 0.125..Valid accuracy: 0.010
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 0.243..Valid accuracy: 0.022
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 0.356..Valid accuracy: 0.036
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 0.462..Valid accuracy: 0.056
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 0.576..Valid accuracy: 0.072
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 0.688..Valid accuracy: 0.088
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 0.807..Valid accuracy: 0.102
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 0.919..Valid accuracy: 0.120
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 1.035..Valid accuracy: 0.136
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 1.150..Valid accuracy: 0.151
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 1.282..Valid accuracy: 0.162
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 1.399..Valid accuracy: 0.178
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 1.508..Valid accuracy: 0.192
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 1.632..Valid accuracy: 0.203
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 1.754..Valid accuracy: 0.220
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 1.864..Valid accuracy: 0.233
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 1.986..Valid accuracy: 0.246
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 2.116..Valid accuracy: 0.256
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 2.222..Valid accuracy: 0.275
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 2.341..Valid accuracy: 0.288
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 2.472..Valid accuracy: 0.299
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 2.594..Valid accuracy: 0.312
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 2.724..Valid accuracy: 0.322
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 2.849..Valid accuracy: 0.335
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 2.965..Valid accuracy: 0.353
# Epoch 1/10.. Train loss: 3.439.. Valid loss: 3.070..Valid accuracy: 0.373
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 0.114..Valid accuracy: 0.013
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 0.230..Valid accuracy: 0.031
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 0.340..Valid accuracy: 0.049
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 0.452..Valid accuracy: 0.065
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 0.552..Valid accuracy: 0.085
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 0.667..Valid accuracy: 0.100
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 0.774..Valid accuracy: 0.113
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 0.901..Valid accuracy: 0.126
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 1.017..Valid accuracy: 0.142
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 1.127..Valid accuracy: 0.157
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 1.240..Valid accuracy: 0.169
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 1.361..Valid accuracy: 0.181
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 1.461..Valid accuracy: 0.201
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 1.577..Valid accuracy: 0.216
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 1.687..Valid accuracy: 0.231
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 1.794..Valid accuracy: 0.246
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 1.913..Valid accuracy: 0.260
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 2.036..Valid accuracy: 0.275
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 2.152..Valid accuracy: 0.287
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 2.268..Valid accuracy: 0.303
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 2.386..Valid accuracy: 0.312
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 2.490..Valid accuracy: 0.333
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 2.608..Valid accuracy: 0.344
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 2.721..Valid accuracy: 0.362
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 2.833..Valid accuracy: 0.382
# Epoch 1/10.. Train loss: 3.337.. Valid loss: 2.942..Valid accuracy: 0.397
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 0.102..Valid accuracy: 0.023
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 0.210..Valid accuracy: 0.040
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 0.321..Valid accuracy: 0.058
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 0.432..Valid accuracy: 0.071
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 0.541..Valid accuracy: 0.088
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 0.649..Valid accuracy: 0.106
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 0.764..Valid accuracy: 0.119
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 0.870..Valid accuracy: 0.133
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 0.967..Valid accuracy: 0.156
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 1.075..Valid accuracy: 0.175
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 1.174..Valid accuracy: 0.194
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 1.286..Valid accuracy: 0.207
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 1.393..Valid accuracy: 0.224
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 1.515..Valid accuracy: 0.236
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 1.617..Valid accuracy: 0.254
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 1.731..Valid accuracy: 0.273
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 1.851..Valid accuracy: 0.284
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 1.959..Valid accuracy: 0.302
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 2.072..Valid accuracy: 0.320
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 2.186..Valid accuracy: 0.335
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 2.286..Valid accuracy: 0.355
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 2.400..Valid accuracy: 0.369
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 2.506..Valid accuracy: 0.387
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 2.612..Valid accuracy: 0.405
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 2.719..Valid accuracy: 0.421
# Epoch 1/10.. Train loss: 3.182.. Valid loss: 2.826..Valid accuracy: 0.436
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 0.096..Valid accuracy: 0.022
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 0.211..Valid accuracy: 0.030
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 0.335..Valid accuracy: 0.044
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 0.443..Valid accuracy: 0.058
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 0.552..Valid accuracy: 0.072
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 0.647..Valid accuracy: 0.097
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 0.749..Valid accuracy: 0.117
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 0.862..Valid accuracy: 0.130
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 0.966..Valid accuracy: 0.149
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 1.065..Valid accuracy: 0.167
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 1.176..Valid accuracy: 0.184
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 1.300..Valid accuracy: 0.196
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 1.393..Valid accuracy: 0.216
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 1.499..Valid accuracy: 0.233
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 1.612..Valid accuracy: 0.248
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 1.708..Valid accuracy: 0.268
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 1.805..Valid accuracy: 0.288
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 1.915..Valid accuracy: 0.304
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 2.016..Valid accuracy: 0.322
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 2.134..Valid accuracy: 0.335
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 2.241..Valid accuracy: 0.351
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 2.351..Valid accuracy: 0.364
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 2.455..Valid accuracy: 0.382
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 2.558..Valid accuracy: 0.403
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 2.683..Valid accuracy: 0.413
# Epoch 1/10.. Train loss: 3.250.. Valid loss: 2.793..Valid accuracy: 0.428
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 0.100..Valid accuracy: 0.018
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 0.205..Valid accuracy: 0.034
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 0.313..Valid accuracy: 0.052
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 0.418..Valid accuracy: 0.069
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 0.503..Valid accuracy: 0.091
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 0.618..Valid accuracy: 0.102
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 0.721..Valid accuracy: 0.119
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 0.837..Valid accuracy: 0.136
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 0.929..Valid accuracy: 0.157
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.033..Valid accuracy: 0.177
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.134..Valid accuracy: 0.192
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.225..Valid accuracy: 0.213
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.326..Valid accuracy: 0.233
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.438..Valid accuracy: 0.250
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.549..Valid accuracy: 0.263
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.649..Valid accuracy: 0.285
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.753..Valid accuracy: 0.302
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.862..Valid accuracy: 0.319
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 1.960..Valid accuracy: 0.337
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 2.078..Valid accuracy: 0.350
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 2.178..Valid accuracy: 0.365
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 2.286..Valid accuracy: 0.379
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 2.386..Valid accuracy: 0.397
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 2.474..Valid accuracy: 0.419
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 2.583..Valid accuracy: 0.435
# Epoch 1/10.. Train loss: 3.348.. Valid loss: 2.684..Valid accuracy: 0.454
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 0.106..Valid accuracy: 0.017
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 0.204..Valid accuracy: 0.038
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 0.310..Valid accuracy: 0.053
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 0.413..Valid accuracy: 0.069
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 0.516..Valid accuracy: 0.082
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 0.611..Valid accuracy: 0.100
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 0.723..Valid accuracy: 0.117
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 0.818..Valid accuracy: 0.136
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 0.924..Valid accuracy: 0.154
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.026..Valid accuracy: 0.168
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.129..Valid accuracy: 0.183
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.219..Valid accuracy: 0.203
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.326..Valid accuracy: 0.220
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.430..Valid accuracy: 0.238
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.533..Valid accuracy: 0.257
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.634..Valid accuracy: 0.270
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.730..Valid accuracy: 0.290
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.826..Valid accuracy: 0.306
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 1.929..Valid accuracy: 0.322
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 2.037..Valid accuracy: 0.335
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 2.131..Valid accuracy: 0.356
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 2.243..Valid accuracy: 0.365
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 2.325..Valid accuracy: 0.392
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 2.404..Valid accuracy: 0.418
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 2.516..Valid accuracy: 0.429
# Epoch 1/10.. Train loss: 3.140.. Valid loss: 2.605..Valid accuracy: 0.450
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.091..Valid accuracy: 0.018
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.197..Valid accuracy: 0.035
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.304..Valid accuracy: 0.052
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.400..Valid accuracy: 0.071
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.499..Valid accuracy: 0.091
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.589..Valid accuracy: 0.111
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.681..Valid accuracy: 0.130
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.787..Valid accuracy: 0.144
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.888..Valid accuracy: 0.160
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 0.981..Valid accuracy: 0.180
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.084..Valid accuracy: 0.196
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.176..Valid accuracy: 0.220
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.256..Valid accuracy: 0.244
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.335..Valid accuracy: 0.269
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.435..Valid accuracy: 0.292
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.525..Valid accuracy: 0.312
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.608..Valid accuracy: 0.338
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.689..Valid accuracy: 0.362
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.784..Valid accuracy: 0.381
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.875..Valid accuracy: 0.399
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 1.981..Valid accuracy: 0.411
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 2.076..Valid accuracy: 0.430
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 2.178..Valid accuracy: 0.448
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 2.275..Valid accuracy: 0.468
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 2.370..Valid accuracy: 0.488
# Epoch 2/10.. Train loss: 1.127.. Valid loss: 2.498..Valid accuracy: 0.499
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.088..Valid accuracy: 0.020
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.186..Valid accuracy: 0.040
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.274..Valid accuracy: 0.060
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.374..Valid accuracy: 0.081
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.475..Valid accuracy: 0.099
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.573..Valid accuracy: 0.118
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.670..Valid accuracy: 0.135
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.764..Valid accuracy: 0.156
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.861..Valid accuracy: 0.173
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 0.962..Valid accuracy: 0.189
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.057..Valid accuracy: 0.209
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.145..Valid accuracy: 0.231
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.246..Valid accuracy: 0.250
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.320..Valid accuracy: 0.276
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.422..Valid accuracy: 0.292
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.509..Valid accuracy: 0.315
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.609..Valid accuracy: 0.333
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.696..Valid accuracy: 0.357
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.775..Valid accuracy: 0.383
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.873..Valid accuracy: 0.400
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 1.958..Valid accuracy: 0.423
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 2.044..Valid accuracy: 0.444
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 2.130..Valid accuracy: 0.465
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 2.202..Valid accuracy: 0.489
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 2.289..Valid accuracy: 0.511
# Epoch 2/10.. Train loss: 2.886.. Valid loss: 2.379..Valid accuracy: 0.530
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.094..Valid accuracy: 0.023
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.186..Valid accuracy: 0.041
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.275..Valid accuracy: 0.060
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.369..Valid accuracy: 0.079
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.460..Valid accuracy: 0.105
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.541..Valid accuracy: 0.133
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.627..Valid accuracy: 0.155
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.717..Valid accuracy: 0.173
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.806..Valid accuracy: 0.194
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.885..Valid accuracy: 0.218
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 0.971..Valid accuracy: 0.238
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.057..Valid accuracy: 0.260
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.165..Valid accuracy: 0.278
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.261..Valid accuracy: 0.297
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.344..Valid accuracy: 0.325
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.431..Valid accuracy: 0.349
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.514..Valid accuracy: 0.374
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.600..Valid accuracy: 0.395
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.693..Valid accuracy: 0.416
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.786..Valid accuracy: 0.435
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.873..Valid accuracy: 0.462
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 1.977..Valid accuracy: 0.486
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 2.051..Valid accuracy: 0.508
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 2.138..Valid accuracy: 0.528
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 2.236..Valid accuracy: 0.548
# Epoch 2/10.. Train loss: 2.934.. Valid loss: 2.323..Valid accuracy: 0.578
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.071..Valid accuracy: 0.023
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.155..Valid accuracy: 0.047
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.240..Valid accuracy: 0.071
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.330..Valid accuracy: 0.088
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.421..Valid accuracy: 0.106
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.506..Valid accuracy: 0.124
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.602..Valid accuracy: 0.138
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.689..Valid accuracy: 0.160
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.768..Valid accuracy: 0.181
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.848..Valid accuracy: 0.200
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 0.938..Valid accuracy: 0.215
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.019..Valid accuracy: 0.238
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.101..Valid accuracy: 0.266
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.175..Valid accuracy: 0.291
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.262..Valid accuracy: 0.315
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.350..Valid accuracy: 0.334
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.434..Valid accuracy: 0.357
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.523..Valid accuracy: 0.382
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.609..Valid accuracy: 0.403
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.699..Valid accuracy: 0.422
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.783..Valid accuracy: 0.445
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.878..Valid accuracy: 0.463
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 1.960..Valid accuracy: 0.486
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 2.039..Valid accuracy: 0.511
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 2.141..Valid accuracy: 0.524
# Epoch 2/10.. Train loss: 2.744.. Valid loss: 2.237..Valid accuracy: 0.541
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.092..Valid accuracy: 0.020
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.179..Valid accuracy: 0.041
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.258..Valid accuracy: 0.064
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.336..Valid accuracy: 0.088
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.406..Valid accuracy: 0.113
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.492..Valid accuracy: 0.132
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.579..Valid accuracy: 0.153
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.652..Valid accuracy: 0.177
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.730..Valid accuracy: 0.198
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.815..Valid accuracy: 0.219
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.911..Valid accuracy: 0.232
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 0.996..Valid accuracy: 0.251
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.068..Valid accuracy: 0.278
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.157..Valid accuracy: 0.299
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.249..Valid accuracy: 0.317
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.326..Valid accuracy: 0.340
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.411..Valid accuracy: 0.361
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.482..Valid accuracy: 0.385
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.565..Valid accuracy: 0.410
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.653..Valid accuracy: 0.429
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.722..Valid accuracy: 0.454
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.810..Valid accuracy: 0.474
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.890..Valid accuracy: 0.495
# Epoch 2/10.. Train loss: 2.714.. Valid loss: 1.955..Valid accuracy: 0.520
# ...
# Epoch 10/10.. Train loss: 0.899.. Valid loss: 0.276..Valid accuracy: 0.785
# Epoch 10/10.. Train loss: 0.899.. Valid loss: 0.290..Valid accuracy: 0.820
# Epoch 10/10.. Train loss: 0.899.. Valid loss: 0.310..Valid accuracy: 0.853
# Epoch 10/10.. Train loss: 0.899.. Valid loss: 0.320..Valid accuracy: 0.889
# Epoch 10/10.. Train loss: 0.899.. Valid loss: 0.348..Valid accuracy: 0.915
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.019..Valid accuracy: 0.032
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.029..Valid accuracy: 0.069
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.038..Valid accuracy: 0.106
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.054..Valid accuracy: 0.141
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.069..Valid accuracy: 0.175
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.087..Valid accuracy: 0.212
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.096..Valid accuracy: 0.248
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.107..Valid accuracy: 0.284
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.116..Valid accuracy: 0.321
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.134..Valid accuracy: 0.355
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.144..Valid accuracy: 0.391
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.155..Valid accuracy: 0.425
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.165..Valid accuracy: 0.460
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.173..Valid accuracy: 0.499
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.185..Valid accuracy: 0.535
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.226..Valid accuracy: 0.566
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.241..Valid accuracy: 0.599
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.257..Valid accuracy: 0.632
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.264..Valid accuracy: 0.668
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.274..Valid accuracy: 0.703
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.283..Valid accuracy: 0.740
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.298..Valid accuracy: 0.773
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.302..Valid accuracy: 0.811
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.311..Valid accuracy: 0.847
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.320..Valid accuracy: 0.885
# Epoch 10/10.. Train loss: 0.816.. Valid loss: 0.334..Valid accuracy: 0.919
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.014..Valid accuracy: 0.035
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.022..Valid accuracy: 0.073
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.028..Valid accuracy: 0.111
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.040..Valid accuracy: 0.145
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.046..Valid accuracy: 0.183
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.054..Valid accuracy: 0.219
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.063..Valid accuracy: 0.257
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.085..Valid accuracy: 0.290
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.101..Valid accuracy: 0.326
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.134..Valid accuracy: 0.361
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.138..Valid accuracy: 0.397
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.160..Valid accuracy: 0.429
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.171..Valid accuracy: 0.464
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.183..Valid accuracy: 0.499
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.191..Valid accuracy: 0.536
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.197..Valid accuracy: 0.573
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.208..Valid accuracy: 0.609
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.223..Valid accuracy: 0.644
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.235..Valid accuracy: 0.678
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.245..Valid accuracy: 0.713
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.258..Valid accuracy: 0.749
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.274..Valid accuracy: 0.784
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.291..Valid accuracy: 0.819
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.304..Valid accuracy: 0.856
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.313..Valid accuracy: 0.892
# Epoch 10/10.. Train loss: 0.920.. Valid loss: 0.329..Valid accuracy: 0.926
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.022..Valid accuracy: 0.036
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.032..Valid accuracy: 0.075
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.052..Valid accuracy: 0.109
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.060..Valid accuracy: 0.145
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.071..Valid accuracy: 0.181
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.090..Valid accuracy: 0.213
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.101..Valid accuracy: 0.250
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.109..Valid accuracy: 0.287
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.116..Valid accuracy: 0.325
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.123..Valid accuracy: 0.362
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.135..Valid accuracy: 0.398
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.148..Valid accuracy: 0.433
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.162..Valid accuracy: 0.468
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.193..Valid accuracy: 0.502
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.203..Valid accuracy: 0.538
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.214..Valid accuracy: 0.575
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.226..Valid accuracy: 0.609
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.240..Valid accuracy: 0.644
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.247..Valid accuracy: 0.681
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.252..Valid accuracy: 0.719
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.263..Valid accuracy: 0.756
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.281..Valid accuracy: 0.791
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.296..Valid accuracy: 0.826
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.305..Valid accuracy: 0.861
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.319..Valid accuracy: 0.895
# Epoch 10/10.. Train loss: 0.831.. Valid loss: 0.338..Valid accuracy: 0.930
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.011..Valid accuracy: 0.035
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.030..Valid accuracy: 0.067
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.046..Valid accuracy: 0.101
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.057..Valid accuracy: 0.138
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.063..Valid accuracy: 0.175
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.076..Valid accuracy: 0.210
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.081..Valid accuracy: 0.249
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.107..Valid accuracy: 0.282
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.115..Valid accuracy: 0.319
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.128..Valid accuracy: 0.353
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.144..Valid accuracy: 0.389
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.156..Valid accuracy: 0.424
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.160..Valid accuracy: 0.463
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.169..Valid accuracy: 0.500
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.182..Valid accuracy: 0.536
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.191..Valid accuracy: 0.572
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.203..Valid accuracy: 0.608
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.237..Valid accuracy: 0.643
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.246..Valid accuracy: 0.679
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.258..Valid accuracy: 0.714
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.271..Valid accuracy: 0.748
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.287..Valid accuracy: 0.781
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.300..Valid accuracy: 0.816
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.313..Valid accuracy: 0.852
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.320..Valid accuracy: 0.891
# Epoch 10/10.. Train loss: 0.885.. Valid loss: 0.343..Valid accuracy: 0.923
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.017..Valid accuracy: 0.035
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.026..Valid accuracy: 0.071
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.032..Valid accuracy: 0.108
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.039..Valid accuracy: 0.147
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.053..Valid accuracy: 0.178
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.060..Valid accuracy: 0.215
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.074..Valid accuracy: 0.250
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.085..Valid accuracy: 0.287
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.102..Valid accuracy: 0.321
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.132..Valid accuracy: 0.355
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.150..Valid accuracy: 0.391
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.160..Valid accuracy: 0.428
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.176..Valid accuracy: 0.464
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.183..Valid accuracy: 0.501
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.190..Valid accuracy: 0.536
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.203..Valid accuracy: 0.571
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.212..Valid accuracy: 0.608
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.219..Valid accuracy: 0.645
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.235..Valid accuracy: 0.680
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.260..Valid accuracy: 0.713
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.272..Valid accuracy: 0.749
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.282..Valid accuracy: 0.785
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.294..Valid accuracy: 0.821
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.308..Valid accuracy: 0.856
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.311..Valid accuracy: 0.894
# Epoch 10/10.. Train loss: 0.894.. Valid loss: 0.328..Valid accuracy: 0.928
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.018..Valid accuracy: 0.034
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.036..Valid accuracy: 0.066
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.048..Valid accuracy: 0.102
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.062..Valid accuracy: 0.136
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.076..Valid accuracy: 0.171
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.086..Valid accuracy: 0.207
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.102..Valid accuracy: 0.242
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.114..Valid accuracy: 0.278
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.120..Valid accuracy: 0.315
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.135..Valid accuracy: 0.351
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.141..Valid accuracy: 0.389
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.145..Valid accuracy: 0.428
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.161..Valid accuracy: 0.460
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.172..Valid accuracy: 0.496
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.192..Valid accuracy: 0.529
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.197..Valid accuracy: 0.566
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.228..Valid accuracy: 0.602
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.235..Valid accuracy: 0.639
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.251..Valid accuracy: 0.675
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.265..Valid accuracy: 0.710
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.270..Valid accuracy: 0.748
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.286..Valid accuracy: 0.782
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.299..Valid accuracy: 0.819
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.314..Valid accuracy: 0.850
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.323..Valid accuracy: 0.887
# Epoch 10/10.. Train loss: 0.740.. Valid loss: 0.333..Valid accuracy: 0.925
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.011..Valid accuracy: 0.036
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.034..Valid accuracy: 0.069
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.051..Valid accuracy: 0.103
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.067..Valid accuracy: 0.138
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.076..Valid accuracy: 0.174
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.090..Valid accuracy: 0.210
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.102..Valid accuracy: 0.246
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.110..Valid accuracy: 0.284
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.123..Valid accuracy: 0.320
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.137..Valid accuracy: 0.353
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.168..Valid accuracy: 0.388
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.181..Valid accuracy: 0.423
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.192..Valid accuracy: 0.458
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.205..Valid accuracy: 0.493
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.211..Valid accuracy: 0.530
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.229..Valid accuracy: 0.561
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.239..Valid accuracy: 0.599
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.250..Valid accuracy: 0.635
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.261..Valid accuracy: 0.672
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.268..Valid accuracy: 0.709
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.283..Valid accuracy: 0.744
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.297..Valid accuracy: 0.776
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.309..Valid accuracy: 0.811
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.322..Valid accuracy: 0.847
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.339..Valid accuracy: 0.881
# Epoch 10/10.. Train loss: 0.937.. Valid loss: 0.350..Valid accuracy: 0.915
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.012..Valid accuracy: 0.035
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.023..Valid accuracy: 0.071
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.039..Valid accuracy: 0.106
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.054..Valid accuracy: 0.141
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.071..Valid accuracy: 0.174
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.095..Valid accuracy: 0.206
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.104..Valid accuracy: 0.243
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.112..Valid accuracy: 0.280
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.120..Valid accuracy: 0.319
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.134..Valid accuracy: 0.353
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.145..Valid accuracy: 0.389
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.154..Valid accuracy: 0.425
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.163..Valid accuracy: 0.464
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.174..Valid accuracy: 0.499
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.198..Valid accuracy: 0.531
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.210..Valid accuracy: 0.565
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.221..Valid accuracy: 0.600
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.258..Valid accuracy: 0.632
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.274..Valid accuracy: 0.665
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.278..Valid accuracy: 0.702
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.292..Valid accuracy: 0.736
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.299..Valid accuracy: 0.773
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.308..Valid accuracy: 0.810
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.324..Valid accuracy: 0.845
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.340..Valid accuracy: 0.880
# Epoch 10/10.. Train loss: 0.967.. Valid loss: 0.348..Valid accuracy: 0.916

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# validation on the test set
def Accuracy_test (testloader):    
    correct = 0
    total = 0
    model.to('cuda:0')
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the images: %d %%' % (100 * correct / total))
    
Accuracy_test(testloader)
# Out:
# Accuracy of the images: 78 %

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# define the model architecture
model.class_to_idx = trainset.class_to_idx
checkpoint = {'classifier': model.classifier,
              'arch': 'densenet121',
              'optimizer_state': optimizer.state_dict,
             'class_to_idx': trainset.class_to_idx,
             'state_dict':model.state_dict(),
             'num_epochs': epochs}

# save the checkpoint
torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def build(path):
    checkpoint = torch.load(path)
    checkpoint = torch.load(path, map_location=lambda storage, loc: storage)
    
    model = getattr(models, chekpoint['arch'](pretrained=True))
    model.classifier = checkpoint['classifier']
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    model.load_state_dict(checkpoint['optimizer_state'])
    
    return model

# %%
model.load_state_dict(checkpoint['state_dict'])
print(model)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1024, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=256, out_features=102, bias=True)
#     (4): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    
    preprocess = transforms.Compose([transforms.Resize(256),
                                    transforms.CenterCrop(224),
                                    transforms.ToTensor(),
                                   transforms.Normalize([0.485, 0.456, 0.406],
                                                       [0.229, 0.224, 0.225])])
    from PIL import Image
    pil_image = Image.open(image)
    pil_image = preprocess(pil_image)
    
    np_image = np.array(pil_image)    

    
    return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax
imshow(process_image("flowers/test/1/image_06743.jpg"))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file 
    
    image = Image.open(image_path)
    image = process_image(image_path)
    print(image.shape)
    image = torch.FloatTensor(image)
    image = image.unsqueeze_(0) #since we are using only one image hence need to vonvert the dimension to (1, 224, 224, 3)
    
    
    output = model(image)
    ps = torch.exp(output)
        
    probs, top_class = torch.topk(ps,topk)
    
    return probs, top_class

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
model.to('cpu')
plt.figure(figsize=(3,3))
path = ('flowers/test/1/image_06743.jpg') 
probs, classes = predict(path, model)
idx_to_class = {v: k for k, v in model.class_to_idx.items()}
prob_arr = probs.data.numpy()[0]
pred_indexes = classes.data.numpy()[0].tolist()    
pred_labels = [idx_to_class[x] for x in pred_indexes]
pred_class = [cat_to_name[str(x)] for x in pred_labels]
#image = process_image(Image.open(path)) 
image = process_image(path) 
max_index = classes[0]
axs = imshow(image, ax = plt)
axs.axis('off')
axs.title(pred_class[0])
axs.show()
fig, ax = plt.subplots()
#names = [cat_to_name[str(index.tolist()+1)] for index in classes[0]]
y_pos = np.arange(len(pred_class))
plt.barh(y_pos, list(reversed(prob_arr)))
plt.yticks(y_pos, list(reversed(pred_class)))
plt.ylabel('Flower Type')
plt.xlabel('Class Probability');
# Out:
# (3, 224, 224)
